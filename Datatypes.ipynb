# %%
marks = [21,43,54,55,94]
print(marks)
# Out:
# [21, 43, 54, 55, 94]

# %%
marks.append(33)
print(marks)
# Out:
# [21, 43, 54, 55, 94, 33]

# %%
rank = (33,44,224,2244,1)
print(rank[2])
# Out:
# 224

# %%
sets = {32, 'eshan', 3.14, "hello", "hello"}
print(sets)
# Out:
# {32, 'hello', 3.14, 'eshan'}

# %%
dict = {
    "name": "Eshan",
    "age": 22,
    "marks": [22,44,53]
}
print(dict["marks"])
# Out:
# [22, 44, 53]

# %%
string = "Eshan"
print(string[0],string[-1])
# Out:
# E n
